# %% [markdown]
# # Random Forest Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt

# %% [markdown]
# ## Importing the dataset

# %%
data_set = pd.read_csv("./Position_Salaries.csv").values 

X = data_set[:,1:-1]
y = data_set[:,-1]

# %% [markdown]
# ## Training the Random Forest Regression model on the whole dataset

# %%
from sklearn.ensemble import RandomForestRegressor
rfr_model = RandomForestRegressor(n_estimators=10,random_state=0)

rfr_model.fit(X,y)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %% [markdown]
# ## Predicting a new result

# %%
print(rfr_model.predict([[6.5]]))
# Out:
# [167000.]

# %% [markdown]
# ## Visualising the Random Forest Regression results (higher resolution)

# %%
X_grid = np.arange(np.min(X), np.max(X), 0.1)
X_grid = X_grid.reshape(len(X_grid), 1)

plt.scatter(X, y, color="red")

y_prediction = rfr_model.predict(X_grid)

plt.plot(X_grid, y_prediction)

plt.title("Salary Prediction (SVR)")
plt.xlabel("Position Level")
plt.ylabel("Salary")

plt.show()
