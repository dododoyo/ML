# %% [markdown]
# ## Grid Detection

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np 
import cv2 as cv
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import Image

# %%
flat_chess = cv.imread("../data/Files/DATA/flat_chessboard.png")
# flat_chess = cv.cvtColor(flat_chess, cv.COLOR_BGR2RGB)

# %%
gridSize = (7,7)
found,corners = cv.findChessboardCorners(image=flat_chess,patternSize=gridSize)

cv.drawChessboardCorners(flat_chess,gridSize,corners,found)

plt.imshow(flat_chess)

# %%
dot_grid = cv.imread("../data/Files/DATA/dot_grid.png")
dotGridSize = (10,10)
# plt.imshow(dot_grid)
dotsFound,dotsCorner = cv.findCirclesGrid(dot_grid,dotGridSize,cv.CALIB_CB_SYMMETRIC_GRID)

cv.drawChessboardCorners(dot_grid, dotGridSize, dotsCorner, dotsFound)

plt.imshow(dot_grid)
